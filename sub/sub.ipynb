# %%
# !pip install /kaggle/input/spaceship-titanic-deps/*.whl \
    --force-reinstall \
    --root-user-action ignore \
    --no-deps \
    --no-index \
    --find-links /kaggle/input/spaceship-titanic-deps

# %%
# !PYTHONPATH=/kaggle/input/spaceship-titanic-codes \
  python /kaggle/input/spaceship-titanic-codes/experiments/001/sample_submission.py
